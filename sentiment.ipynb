# %%
import os
import pandas as pd
import numpy as np
import keras
import boto3
import sagemaker
import tensorflow as tf
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# 17465344/17464789 [==============================] - 3s 0us/step

# %%
df_train = pd.DataFrame({'sentences': X_train, 'sentiment': y_train}, columns=['sentences', 'sentiment'])[0:2000]
df_test = pd.DataFrame({'sentences': X_test, 'sentiment': y_test}, columns=['sentences', 'sentiment'])[0:2000]

os.makedirs('./data', exist_ok=True)

df_train.to_csv('data/train.csv', index=False)
df_test.to_csv('data/test.csv', index=False)

sagemaker_session = sagemaker.Session(default_bucket='my-sagemaker-data-bucket')
prefix = 'sentient_classification'
training_input_path = sagemaker_session.upload_data('data/train.csv', key_prefix=prefix+'/train')
testing_input_path = sagemaker_session.upload_data('data/test.csv', key_prefix=prefix+'/test')

# %%
tf_version = tf.__version__
role = sagemaker.get_execution_role()

from sagemaker.tensorflow import TensorFlow
import subprocess

instance_type = 'local'#'ml.p3.8xlarge'
# Check if local GPU is present
if subprocess.call('nvidia-smi') == 0:
    print('GPU present')
    instance_type = 'local_gpu'

tf_estimator = TensorFlow(entry_point='train_sentiment.py',
                          role=role,
                          train_instance_count=2,
                          instance_type=instance_type,
                          py_version='py37',
                          framework_version='2.3.2',
                          distribution={
                              'mpi': {
                                  'enabled': True,
                                  'processes_per_host': 1
                              }
                          },
                          hyperparameters={
                              'epochs': 1,
                              'batch-size': 32
                          })

tf_estimator.fit({'train': training_input_path})
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Creating veo4szvq41-algo-1-brzc3 ...
# Creating tvploak8d5-algo-2-brzc3 ...
# Creating veo4szvq41-algo-1-brzc3 ... done
# Creating tvploak8d5-algo-2-brzc3 ... done
# Attaching to veo4szvq41-algo-1-brzc3, tvploak8d5-algo-2-brzc3
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:26.017037: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:26.017469: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:26.017044: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:26.017471: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:26.049713: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:26.051968: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,577 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,579 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,594 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,598 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,809 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,809 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,833 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,836 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,846 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,846 sagemaker-training-toolkit INFO     Creating SSH daemon.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,852 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,853 sagemaker-training-toolkit INFO     Waiting for MPI Master to create SSH daemon.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,854 sagemaker-training-toolkit INFO     Cannot connect to host algo-1-brzc3
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:28,854 sagemaker-training-toolkit INFO     Connection failed with exception:
# tvploak8d5-algo-2-brzc3 |  [Errno None] Unable to connect to port 22 on 172.18.0.2
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,855 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,857 sagemaker-training-toolkit INFO     Cannot connect to host algo-2-brzc3
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:28,857 sagemaker-training-toolkit INFO     Connection failed with exception:
# veo4szvq41-algo-1-brzc3 |  [Errno None] Unable to connect to port 22 on 172.18.0.3
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:29,859 sagemaker-training-toolkit INFO     Cannot connect to host algo-2-brzc3
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:29,859 sagemaker-training-toolkit INFO     Connection failed with exception:
# veo4szvq41-algo-1-brzc3 |  [Errno None] Unable to connect to port 22 on 172.18.0.3
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,863 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,981 paramiko.transport INFO     Authentication (publickey) successful!
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,982 sagemaker-training-toolkit INFO     Can connect to host algo-1-brzc3
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,982 sagemaker-training-toolkit INFO     MPI Master online, creating SSH daemon.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,982 sagemaker-training-toolkit INFO     Writing environment variables to /etc/environment for the MPI process.
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:29,993 sagemaker-training-toolkit INFO     Waiting for MPI process to finish.
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,868 paramiko.transport INFO     Connected (version 2.0, client OpenSSH_7.6p1)
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,923 paramiko.transport INFO     Authentication (publickey) successful!
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,924 sagemaker-training-toolkit INFO     Can connect to host algo-2-brzc3
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,924 sagemaker-training-toolkit INFO     Worker algo-2-brzc3 available for communication
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,925 sagemaker-training-toolkit INFO     Env Hosts: ['algo-1-brzc3', 'algo-2-brzc3'] Hosts: ['algo-1-brzc3', 'algo-2-brzc3'] process_per_hosts: 1 num_processes: 2
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,926 sagemaker-training-toolkit INFO     Network interface name: eth0
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,934 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:22:30,947 sagemaker-training-toolkit INFO     Invoking user script
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | Training Env:
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | {
# veo4szvq41-algo-1-brzc3 |     "additional_framework_parameters": {
# veo4szvq41-algo-1-brzc3 |         "sagemaker_mpi_enabled": true,
# veo4szvq41-algo-1-brzc3 |         "sagemaker_mpi_num_of_processes_per_host": 1,
# veo4szvq41-algo-1-brzc3 |         "sagemaker_mpi_custom_mpi_options": ""
# veo4szvq41-algo-1-brzc3 |     },
# veo4szvq41-algo-1-brzc3 |     "channel_input_dirs": {
# veo4szvq41-algo-1-brzc3 |         "train": "/opt/ml/input/data/train"
# veo4szvq41-algo-1-brzc3 |     },
# veo4szvq41-algo-1-brzc3 |     "current_host": "algo-1-brzc3",
# veo4szvq41-algo-1-brzc3 |     "framework_module": "sagemaker_tensorflow_container.training:main",
# veo4szvq41-algo-1-brzc3 |     "hosts": [
# veo4szvq41-algo-1-brzc3 |         "algo-1-brzc3",
# veo4szvq41-algo-1-brzc3 |         "algo-2-brzc3"
# veo4szvq41-algo-1-brzc3 |     ],
# veo4szvq41-algo-1-brzc3 |     "hyperparameters": {
# veo4szvq41-algo-1-brzc3 |         "epochs": 1,
# veo4szvq41-algo-1-brzc3 |         "batch-size": 32,
# veo4szvq41-algo-1-brzc3 |         "model_dir": "/opt/ml/model"
# veo4szvq41-algo-1-brzc3 |     },
# veo4szvq41-algo-1-brzc3 |     "input_config_dir": "/opt/ml/input/config",
# veo4szvq41-algo-1-brzc3 |     "input_data_config": {
# veo4szvq41-algo-1-brzc3 |         "train": {
# veo4szvq41-algo-1-brzc3 |             "TrainingInputMode": "File"
# veo4szvq41-algo-1-brzc3 |         }
# veo4szvq41-algo-1-brzc3 |     },
# veo4szvq41-algo-1-brzc3 |     "input_dir": "/opt/ml/input",
# veo4szvq41-algo-1-brzc3 |     "is_master": true,
# veo4szvq41-algo-1-brzc3 |     "job_name": "tensorflow-training-2021-12-21-05-20-57-853",
# veo4szvq41-algo-1-brzc3 |     "log_level": 20,
# veo4szvq41-algo-1-brzc3 |     "master_hostname": "algo-1-brzc3",
# veo4szvq41-algo-1-brzc3 |     "model_dir": "/opt/ml/model",
# veo4szvq41-algo-1-brzc3 |     "module_dir": "s3://sagemaker-us-west-2-185566974780/tensorflow-training-2021-12-21-05-20-57-853/source/sourcedir.tar.gz",
# veo4szvq41-algo-1-brzc3 |     "module_name": "train_sentiment",
# veo4szvq41-algo-1-brzc3 |     "network_interface_name": "eth0",
# veo4szvq41-algo-1-brzc3 |     "num_cpus": 2,
# veo4szvq41-algo-1-brzc3 |     "num_gpus": 0,
# veo4szvq41-algo-1-brzc3 |     "output_data_dir": "/opt/ml/output/data",
# veo4szvq41-algo-1-brzc3 |     "output_dir": "/opt/ml/output",
# veo4szvq41-algo-1-brzc3 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# veo4szvq41-algo-1-brzc3 |     "resource_config": {
# veo4szvq41-algo-1-brzc3 |         "current_host": "algo-1-brzc3",
# veo4szvq41-algo-1-brzc3 |         "hosts": [
# veo4szvq41-algo-1-brzc3 |             "algo-1-brzc3",
# veo4szvq41-algo-1-brzc3 |             "algo-2-brzc3"
# veo4szvq41-algo-1-brzc3 |         ]
# veo4szvq41-algo-1-brzc3 |     },
# veo4szvq41-algo-1-brzc3 |     "user_entry_point": "train_sentiment.py"
# veo4szvq41-algo-1-brzc3 | }
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | Environment variables:
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | SM_HOSTS=["algo-1-brzc3","algo-2-brzc3"]
# veo4szvq41-algo-1-brzc3 | SM_NETWORK_INTERFACE_NAME=eth0
# veo4szvq41-algo-1-brzc3 | SM_HPS={"batch-size":32,"epochs":1,"model_dir":"/opt/ml/model"}
# veo4szvq41-algo-1-brzc3 | SM_USER_ENTRY_POINT=train_sentiment.py
# veo4szvq41-algo-1-brzc3 | SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":1}
# veo4szvq41-algo-1-brzc3 | SM_RESOURCE_CONFIG={"current_host":"algo-1-brzc3","hosts":["algo-1-brzc3","algo-2-brzc3"]}
# veo4szvq41-algo-1-brzc3 | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# veo4szvq41-algo-1-brzc3 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# veo4szvq41-algo-1-brzc3 | SM_CHANNELS=["train"]
# veo4szvq41-algo-1-brzc3 | SM_CURRENT_HOST=algo-1-brzc3
# veo4szvq41-algo-1-brzc3 | SM_MODULE_NAME=train_sentiment
# veo4szvq41-algo-1-brzc3 | SM_LOG_LEVEL=20
# veo4szvq41-algo-1-brzc3 | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# veo4szvq41-algo-1-brzc3 | SM_INPUT_DIR=/opt/ml/input
# veo4szvq41-algo-1-brzc3 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# veo4szvq41-algo-1-brzc3 | SM_OUTPUT_DIR=/opt/ml/output
# veo4szvq41-algo-1-brzc3 | SM_NUM_CPUS=2
# veo4szvq41-algo-1-brzc3 | SM_NUM_GPUS=0
# veo4szvq41-algo-1-brzc3 | SM_MODEL_DIR=/opt/ml/model
# veo4szvq41-algo-1-brzc3 | SM_MODULE_DIR=s3://sagemaker-us-west-2-185566974780/tensorflow-training-2021-12-21-05-20-57-853/source/sourcedir.tar.gz
# veo4szvq41-algo-1-brzc3 | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":1},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-brzc3","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-brzc3","algo-2-brzc3"],"hyperparameters":{"batch-size":32,"epochs":1,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-12-21-05-20-57-853","log_level":20,"master_hostname":"algo-1-brzc3","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-185566974780/tensorflow-training-2021-12-21-05-20-57-853/source/sourcedir.tar.gz","module_name":"train_sentiment","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-brzc3","hosts":["algo-1-brzc3","algo-2-brzc3"]},"user_entry_point":"train_sentiment.py"}
# veo4szvq41-algo-1-brzc3 | SM_USER_ARGS=["--batch-size","32","--epochs","1","--model_dir","/opt/ml/model"]
# veo4szvq41-algo-1-brzc3 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# veo4szvq41-algo-1-brzc3 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# veo4szvq41-algo-1-brzc3 | SM_HP_EPOCHS=1
# veo4szvq41-algo-1-brzc3 | SM_HP_BATCH-SIZE=32
# veo4szvq41-algo-1-brzc3 | SM_HP_MODEL_DIR=/opt/ml/model
# veo4szvq41-algo-1-brzc3 | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | Invoking script with the following command:
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | mpirun --host algo-1-brzc3,algo-2-brzc3 -np 2 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_TRAIN -x SM_HP_EPOCHS -x SM_HP_BATCH-SIZE -x SM_HP_MODEL_DIR -x PYTHONPATH /usr/local/bin/python3.7 -m mpi4py train_sentiment.py --batch-size 32 --epochs 1 --model_dir /opt/ml/model
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |  Data for JOB [53623,1] offset 0 Total slots allocated 2
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |  ========================   JOB MAP   ========================
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |  Data for node: 73b0b1a920f6	Num slots: 1	Max slots: 0	Num procs: 1
# veo4szvq41-algo-1-brzc3 |  	Process OMPI jobid: [53623,1] App: 0 Process rank: 0 Bound: N/A
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |  Data for node: algo-2-brzc3	Num slots: 1	Max slots: 0	Num procs: 1
# veo4szvq41-algo-1-brzc3 |  	Process OMPI jobid: [53623,1] App: 0 Process rank: 1 Bound: N/A
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 |  =============================================================
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:31,999 sagemaker-training-toolkit INFO     Process[es]: [psutil.Process(pid=51, name='orted', status='sleeping', started='05:22:30')]
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:32,000 sagemaker-training-toolkit INFO     Orted process found [psutil.Process(pid=51, name='orted', status='sleeping', started='05:22:30')]
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:22:32,000 sagemaker-training-toolkit INFO     Waiting for orted process [psutil.Process(pid=51, name='orted', status='sleeping', started='05:22:30')]
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Starting training
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Starting training
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Number of GPUs:  2
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Number of GPUs:  2
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Input Shape = (None, 1038)
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Input Shape = (None, 1038)
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:[2021-12-21 05:22:35.324 algo-1-brzc3:45 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:[2021-12-21 05:22:35.327 algo-2-brzc3:54 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:[2021-12-21 05:22:35.575 algo-2-brzc3:54 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:[2021-12-21 05:22:35.577 algo-1-brzc3:45 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Model: "functional_1"[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,0]<stdout>:Model: "functional_1"
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Layer (type)                 Output Shape              Param #
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:=================================================================
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:input_1 (InputLayer)         [(None, 1038)]            0
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:embedding (Embedding)        (None, 1038, 128)         11338880
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:conv1d (Conv1D)              (None, 344, 128)          114816
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:max_pooling1d (MaxPooling1D) (None, 172, 128)          0
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:flatten (Flatten)            (None, 22016)             0
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:dense (Dense)                (None, 20)                440340
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:dense_1 (Dense)              (None, 1)                 21
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:=================================================================
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Total params: 11,894,057
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Trainable params: 11,894,057
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Non-trainable params: 0
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:_________________________________________________________________[1,0]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Model Summary:  None
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Layer (type)                 Output Shape              Param #   [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:=================================================================[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:input_1 (InputLayer)         [(None, 1038)]            0         [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:embedding (Embedding)        (None, 1038, 128)         11338880  [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:conv1d (Conv1D)              (None, 344, 128)          114816    [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:max_pooling1d (MaxPooling1D) (None, 172, 128)          0         [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:flatten (Flatten)            (None, 22016)             0         [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:dense (Dense)                (None, 20)                440340    [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:dense_1 (Dense)              (None, 1)                 21        [1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:=================================================================[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Total params: 11,894,057[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Trainable params: 11,894,057[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Non-trainable params: 0[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:_________________________________________________________________[1,1]<stdout>:
# veo4szvq41-algo-1-brzc3 | [1,1]<stdout>:Model Summary: [1,1]<stdout>: [1,1]<stdout>:None[1,1]<stdout>:
# [1,1]<stdout[1,0]<stdout>:63/63 [==============================] - 29s 468ms/step - loss: 0.5553 - accuracy: 0.7250<stdout[1,1]<stdout>:7046[1,0]<stdout[1,0]<stdout>:
# [1,1]<stdout>:63/63 [==============================][1,1]<stdout>: - 30s 468ms/step - loss: 0.5802 - accuracy: 0.7060
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Instructions for updating:
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Instructions for updating:
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# veo4szvq41-algo-1-brzc3 | [1,0]<stdout>:Assets written to: /opt/ml/model/1/assets
# veo4szvq41-algo-1-brzc3 | Warning: Permanently added 'algo-2-brzc3,172.18.0.3' (ECDSA) to the list of known hosts.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:2021-12-21 05:22:31.697648: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:2021-12-21 05:22:31.697819: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:2021-12-21 05:22:31.736185: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | [1,1]<stderr>:2021-12-21 05:22:31.775336: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | [1,1]<stderr>:2021-12-21 05:22:31.775765: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# veo4szvq41-algo-1-brzc3 | [1,1]<stderr>:2021-12-21 05:22:31.807639: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:Instructions for updating:
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:2021-12-21 05:23:08.541627: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:Instructions for updating:
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# veo4szvq41-algo-1-brzc3 | [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# veo4szvq41-algo-1-brzc3 |
# veo4szvq41-algo-1-brzc3 | 2021-12-21 05:23:09,705 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# tvploak8d5-algo-2-brzc3 | 2021-12-21 05:23:09,731 sagemaker-training-toolkit INFO     Orted process exited
# veo4szvq41-algo-1-brzc3 exited with code 0
# Stopping tvploak8d5-algo-2-brzc3 ...
# Stopping tvploak8d5-algo-2-brzc3 ... done
# Aborting on container exit...
# ===== Job Complete =====

# %%
sentiment_predictor = tf_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Attaching to 2jcjfb5qdd-algo-1-7f189
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:PYTHON SERVICE: False
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:starting services
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:using default model name: model
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:tensorflow serving model config:
# 2jcjfb5qdd-algo-1-7f189 | model_config_list: {
# 2jcjfb5qdd-algo-1-7f189 |   config: {
# 2jcjfb5qdd-algo-1-7f189 |     name: 'model'
# 2jcjfb5qdd-algo-1-7f189 |     base_path: '/opt/ml/model'
# 2jcjfb5qdd-algo-1-7f189 |     model_platform: 'tensorflow'
# 2jcjfb5qdd-algo-1-7f189 |     model_version_policy: {
# 2jcjfb5qdd-algo-1-7f189 |       specific: {
# 2jcjfb5qdd-algo-1-7f189 |         versions: 1
# 2jcjfb5qdd-algo-1-7f189 |       }
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |   }
# 2jcjfb5qdd-algo-1-7f189 | }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:tensorflow version info:
# 2jcjfb5qdd-algo-1-7f189 | TensorFlow ModelServer: 2.3.0-rc0+dev.sha.no_git
# 2jcjfb5qdd-algo-1-7f189 | TensorFlow Library: 2.3.0
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:tensorflow serving command: tensorflow_model_server --port=9000 --rest_api_port=8501 --model_config_file=/sagemaker/model-config.cfg --max_num_load_retries=0
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:started tensorflow serving (pid: 17)
# 2jcjfb5qdd-algo-1-7f189 | INFO:tfs_utils:Trying to connect with model server: http://localhost:8501/v1/models/model
# 2jcjfb5qdd-algo-1-7f189 | WARNING:urllib3.connectionpool:Retrying (Retry(total=8, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fed28332090>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.536156: I tensorflow_serving/model_servers/server_core.cc:464] Adding/updating models.
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.536235: I tensorflow_serving/model_servers/server_core.cc:575]  (Re-)adding model: model
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.636496: I tensorflow_serving/util/retrier.cc:46] Retrying of Reserving resources for servable: {name: model version: 1} exhausted max_num_retries: 0
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.636551: I tensorflow_serving/core/basic_manager.cc:739] Successfully reserved resources to load servable {name: model version: 1}
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.636565: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.636576: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.636608: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:31] Reading SavedModel from: /opt/ml/model/1
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.639873: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:54] Reading meta graph with tags { serve }
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.639906: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:234] Reading SavedModel debug info (if present) from: /opt/ml/model/1
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.641066: I external/org_tensorflow/tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.672846: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:199] Restoring SavedModel bundle.
# 2jcjfb5qdd-algo-1-7f189 | WARNING:urllib3.connectionpool:Retrying (Retry(total=7, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fed283326d0>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.882949: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:183] Running initialization op on SavedModel bundle at path: /opt/ml/model/1
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.893071: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:303] SavedModel load for tags { serve }; Status: success: OK. Took 256458 microseconds.
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.894340: I tensorflow_serving/servables/tensorflow/saved_model_warmup_util.cc:59] No warmup data file found at /opt/ml/model/1/assets.extra/tf_serving_warmup_requests
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.895080: I tensorflow_serving/util/retrier.cc:46] Retrying of Loading servable: {name: model version: 1} exhausted max_num_retries: 0
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.895107: I tensorflow_serving/core/loader_harness.cc:87] Successfully loaded servable version {name: model version: 1}
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.897417: I tensorflow_serving/model_servers/server.cc:367] Running gRPC ModelServer at 0.0.0.0:9000 ...
# 2jcjfb5qdd-algo-1-7f189 | [warn] getaddrinfo: address family for nodename not supported
# 2jcjfb5qdd-algo-1-7f189 | 2021-12-21 05:24:07.898464: I tensorflow_serving/model_servers/server.cc:387] Exporting HTTP/REST API at:localhost:8501 ...
# 2jcjfb5qdd-algo-1-7f189 | [evhttp_server.cc : 238] NET_LOG: Entering the event loop ...
# 2jcjfb5qdd-algo-1-7f189 | WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fed28332b10>: Failed to establish a new connection: [Errno 111] Connection refused')': /v1/models/model
# 2jcjfb5qdd-algo-1-7f189 | INFO:tfs_utils:<Response [200]>
# 2jcjfb5qdd-algo-1-7f189 | INFO:tfs_utils:model: http://localhost:8501/v1/models/model is available now
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:nginx config:
# 2jcjfb5qdd-algo-1-7f189 | load_module modules/ngx_http_js_module.so;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | worker_processes auto;
# 2jcjfb5qdd-algo-1-7f189 | daemon off;
# 2jcjfb5qdd-algo-1-7f189 | pid /tmp/nginx.pid;
# 2jcjfb5qdd-algo-1-7f189 | error_log  /dev/stderr info;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | worker_rlimit_nofile 4096;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | events {
# 2jcjfb5qdd-algo-1-7f189 |   worker_connections 2048;
# 2jcjfb5qdd-algo-1-7f189 | }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | http {
# 2jcjfb5qdd-algo-1-7f189 |   include /etc/nginx/mime.types;
# 2jcjfb5qdd-algo-1-7f189 |   default_type application/json;
# 2jcjfb5qdd-algo-1-7f189 |   access_log /dev/stdout combined;
# 2jcjfb5qdd-algo-1-7f189 |   js_include tensorflow-serving.js;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |   upstream tfs_upstream {
# 2jcjfb5qdd-algo-1-7f189 |     server localhost:8501;
# 2jcjfb5qdd-algo-1-7f189 |   }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |   upstream gunicorn_upstream {
# 2jcjfb5qdd-algo-1-7f189 |     server unix:/tmp/gunicorn.sock fail_timeout=1;
# 2jcjfb5qdd-algo-1-7f189 |   }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |   server {
# 2jcjfb5qdd-algo-1-7f189 |     listen 8080 deferred;
# 2jcjfb5qdd-algo-1-7f189 |     client_max_body_size 0;
# 2jcjfb5qdd-algo-1-7f189 |     client_body_buffer_size 100m;
# 2jcjfb5qdd-algo-1-7f189 |     subrequest_output_buffer_size 100m;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     set $tfs_version 2.3;
# 2jcjfb5qdd-algo-1-7f189 |     set $default_tfs_model model;
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     location /tfs {
# 2jcjfb5qdd-algo-1-7f189 |         rewrite ^/tfs/(.*) /$1  break;
# 2jcjfb5qdd-algo-1-7f189 |         proxy_redirect off;
# 2jcjfb5qdd-algo-1-7f189 |         proxy_pass_request_headers off;
# 2jcjfb5qdd-algo-1-7f189 |         proxy_set_header Content-Type 'application/json';
# 2jcjfb5qdd-algo-1-7f189 |         proxy_set_header Accept 'application/json';
# 2jcjfb5qdd-algo-1-7f189 |         proxy_pass http://tfs_upstream;
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     location /ping {
# 2jcjfb5qdd-algo-1-7f189 |         js_content ping;
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     location /invocations {
# 2jcjfb5qdd-algo-1-7f189 |         js_content invocations;
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     location /models {
# 2jcjfb5qdd-algo-1-7f189 |         proxy_pass http://gunicorn_upstream/models;
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     location / {
# 2jcjfb5qdd-algo-1-7f189 |         return 404 '{"error": "Not Found"}';
# 2jcjfb5qdd-algo-1-7f189 |     }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |     keepalive_timeout 3;
# 2jcjfb5qdd-algo-1-7f189 |   }
# 2jcjfb5qdd-algo-1-7f189 | }
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 |
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:nginx version info:
# 2jcjfb5qdd-algo-1-7f189 | nginx version: nginx/1.20.1
# 2jcjfb5qdd-algo-1-7f189 | built by gcc 7.5.0 (Ubuntu 7.5.0-3ubuntu1~18.04)
# 2jcjfb5qdd-algo-1-7f189 | built with OpenSSL 1.1.1  11 Sep 2018
# 2jcjfb5qdd-algo-1-7f189 | TLS SNI support enabled
# 2jcjfb5qdd-algo-1-7f189 | configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fdebug-prefix-map=/data/builder/debuild/nginx-1.20.1/debian/debuild-base/nginx-1.20.1=. -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# 2jcjfb5qdd-algo-1-7f189 | INFO:__main__:started nginx (pid: 55)
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: using the "epoll" event method
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: nginx/1.20.1
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: built by gcc 7.5.0 (Ubuntu 7.5.0-3ubuntu1~18.04)
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: OS: Linux 4.14.248-129.473.amzn1.x86_64
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: getrlimit(RLIMIT_NOFILE): 32768:65536
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: start worker processes
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: start worker process 56
# 2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:08 [notice] 55#55: start worker process 57
# 2jcjfb5qdd-algo-1-7f189 | 172.18.0.1 - - [21/Dec/2021:05:24:12 +0000] "GET /ping HTTP/1.1" 200 0 "-" "python-urllib3/1.26.7"
# !2jcjfb5qdd-algo-1-7f189 | 2021/12/21 05:24:12 [info] 57#57: *1 client 172.18.0.1 closed keepalive connection

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_word_index = max([max(sentence) for sentence in df_test['sentences']])
max_sentence_length = max([len(sentence) for sentence in df_test['sentences']])
max_sentence_length = 1038
X_test_padded = pad_sequences(df_test['sentences'], maxlen=int(float(max_sentence_length)), padding='post')

predictions = sentiment_predictor.predict(X_test_padded[0:50])
predictions
# Out:
# {'predictions': [[0.537367404],
#   [0.958817422],
#   [0.998868346],
#   [0.034765929],
#   [0.999992073],
#   [0.689996243],
#   [0.1218822],
#   [0.057597667],
#   [0.758380413],
#   [0.960324168],
#   [0.045324266],
#   [0.0739206672],
#   [0.446586251],
#   [0.699089289],
#   [0.97275573],
#   [0.0171760321],
#   [0.983237267],
#   [0.62255621],
#   [0.443494409],
#   [0.576273799],
#   [0.961864948],
#   [0.999987245],
#   [0.954569936],
#   [0.271190047],
#   [0.380440563],
#   [0.0614178181],
#   [0.832692444],
#   [0.582939],
#   [0.440390557],
#   [0.246110827],
#   [0.999573],
#   [0.0354868472],
#   [0.986569762],
#   [0.0166225731],
#   [0.897319198],
#   [0.0101800561],
#   [0.98902142],
#   [0.99781388],
#   [0.078352809],
#   [0.010755986],
#   [0.998691797],
#   [0.997918665],
#   [0.085237056],
#   [0.497526854],
#   [0.998014092],
#   [0.0895275772],
#   [0.0918046534],
#   [0.34136498],
#   [0.32637316],
#   [0.298807502]]}
# 2jcjfb5qdd-algo-1-7f189 | 172.18.0.1 - - [21/Dec/2021:05:24:12 +0000] "POST /invocations HTTP/1.1" 200 769 "-" "python-urllib3/1.26.7"
